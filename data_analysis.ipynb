# %% [markdown]
# ## Physical Rehabilitation Movements Data Set (UI-PRMD)

# %%
# !ls /datasets/movements_rehabilitation_dataset
# Out:
# Incorrect Movements	       Movements	    Segmented Movements.zip
# Incorrect Segmented Movements  Segmented Movements
